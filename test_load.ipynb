# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('mqr_dataset/train_mqr_with_category.tsv',sep='\t')
test = pd.read_csv('mqr_dataset/test_mqr_with_category.tsv', sep='\t')

# %%
train_well = train['well formed']
test_well =test['well formed']

# %%
train_well_first = train_well.map(lambda x: x.split(' ')[0])
test_well_first = test_well.map(lambda x: x.split(' ')[0])

# %%
first = np.append(train_well_first.to_numpy(), test_well_first.to_numpy())

# %%
labels, counts = np.unique(first, return_counts=True)

# %%
included = counts>100
labels_i = labels[included]
counts_i = counts[included]

# %%
from matplotlib import pyplot as plt
plt.pie(percent_i, labels=labels_i, rotatelabels=45)
plt.show()

# %%
what_per = sum(first == 'What')/len(first)

# %%
who_per = sum(first == 'Who')/len(first)

# %%
where_per = sum(first == 'Where')/len(first)

# %%
when_per = sum(first == 'When')/len(first)

# %%
which_per = sum(first == 'Which')/len(first)

# %%
whose_per = sum(first == 'Whose')/len(first)

# %%
how_per = sum(first == 'How')/len(first)

# %%
why_per = sum(first == 'Why')/len(first)

# %%
is_per = sum(first == 'Is')/len(first)

# %%
are_per = sum(first == 'Are')/len(first)

# %%
can_per = sum(first == 'Can')/len(first)

# %%
do_per = sum(first == 'Do')/len(first)

# %%
per = np.array([what_per,who_per,where_per,when_per,which_per,whose_per,how_per,why_per,is_per,are_per,can_per,do_per])*100
per = np.append(per, 100-sum(per))
lab = ['what', 'who', 'where', 'when','which','whose','how','why','is','are','can','do','others']
from matplotlib import pyplot as plt

# %%
plt.pie(per, labels=lab, rotatelabels=45, labeldistance=1.5)
plt.show()

# %%
print(list(zip(per.round(4).tolist(), lab)))
# Out:
# [(16.5622, 'what'), (0.5075, 'who'), (1.617, 'where'), (1.348, 'when'), (1.4516, 'which'), (0.0146, 'whose'), (35.7337, 'how'), (11.3466, 'why'), (11.9086, 'is'), (2.6571, 'are'), (6.6876, 'can'), (2.101, 'do')]

# %%
sum(per[:6])
# Out:
# 21.500821180102772

# %%
baseline_retr = 0.0130748
baseline_reader = 7.13488 -baseline_retr
faiss_retr = 0.30727
distil = 17.3059
baseline_reader
# Out:
# 7.1218052
