# %%
from haystack import document_stores
from haystack.nodes import BM25Retriever, FARMReader
from haystack.pipelines import ExtractiveQAPipeline

# %%
from datasets import load_dataset
from tqdm.notebook import tqdm

# %%
wiki_data = load_dataset("olm/wikipedia", language='simple', date="20221201", split=['train'])
# Out:
# WARNING:datasets.builder:Using custom data configuration 20221201.simple-date=20221201,language=simple
# WARNING:datasets.builder:Found cached dataset wikipedia (/home/ec2-user/.cache/huggingface/datasets/olm___wikipedia/20221201.simple-date=20221201,language=simple/2.0.0/dbfec0358f063ec7ae9e247d6559e2e505fbce7463e666024718863cbf199ec6)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from haystack.utils import launch_es
launch_es()
document_store = document_stores.ElasticsearchDocumentStore()

# %%
import numpy as np
import pandas as pd
rng = np.random.default_rng(12345)
rand_idx = rng.random(50000)*len(wiki_data[0])
wiki_small = pd.DataFrame(data=wiki_data[0][rand_idx])

# %%
wiki_small.iloc[0,:]['text']

# %%
docs = []
batch_size = 1000
# total_doc_count = len(wiki_data)
# total_doc_count = 50000
# print('total_doc_count:', total_doc_count)
for i in tqdm(range(len(wiki_small)), desc='getting wiki articles'):
    to_dict = wiki_small.iloc[i,:]
    doc = {'meta':{'id': to_dict['id'], 'url': to_dict['url'], 'title': to_dict['title']}}
#     print('doc set up. adding text')
    doc['content'] = to_dict['text'] 
    # doc = document_stores.convert_to_doc_dict(article)
    docs.append(doc)
    if i % batch_size == 0:     
      document_store.write_documents(docs)      
      docs.clear()
#     if idx >= total_doc_count:
#       break
# Out:
# getting wiki articles:   0%|          | 0/50000 [00:00<?, ?it/s]

# %%
retriever = BM25Retriever(document_store=document_store)
# reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True)


# pipe = ExtractiveQAPipeline(reader, retriever)

# %%
import json
with open('sample_questions_with_predicted.json','r')as file:
    questions = json.load(file)

# %%
questions[0]
# Out:
# {'category': 'COMMON BONDS',
#  'air_date': '1998-09-07',
#  'question': "'A game of footsie,<br />a bribe,<br />a drunk person'",
#  'value': '$500',
#  'answer': 'Things that are done under the table',
#  'round': 'Jeopardy!',
#  'show_number': '3216',
#  'predicted_question': [['question: What is the difference between a game of footsie,br />a bribe and a drunk person?']]}

# %%
import time
from tqdm.notebook import tqdm
timer = 0
for i in tqdm(range(len(questions))):
    q = questions[i]
    start = time.time()
    candidate_documents = retriever.retrieve(
        query=q['question'],
        top_k=5
    )
    timer += time.time()-start
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
timer/len(questions)
# Out:
# 0.013074764490127563

# %%
jeopardy = "Whose theory did Galileo espouse and was under house arrest as a result for the last 8 years of his life?"
prediction = pipe.run(
    query=jeopardy, params={"Retriever": {"top_k": 5}, "Reader": {"top_k": 1}}
)
# Out:
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.83s/ Batches
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4114/2787786352.py in <module>
#       3     query=jeopardy, params={"Retriever": {"top_k": 5}, "Reader": {"top_k": 1}}
#       4 )
# ----> 5 prediction['answer']
#
# KeyError: 'answer'

# %%
prediction['answers'][0].to_dict()['answer']
# Out:
# 'Galileo Galilei'

# %%
import json
with open('JEOPARDY_QUESTIONS1.json','r') as file:
    questions = json.load(file)
    
rand_q_idx = rng.random(1000)*39495
sample_questions = []
for i in rand_q_idx.astype('int'):
    sample_questions.append(questions[i])

# %%
with open('sample_questions.json','w') as file:
    json.dump(sample_questions, file)

# %%
sample_questions[0]
# Out:
# {'category': 'COMMON BONDS',
#  'air_date': '1998-09-07',
#  'question': "'A game of footsie,<br />a bribe,<br />a drunk person'",
#  'value': '$500',
#  'answer': 'Things that are done under the table',
#  'round': 'Jeopardy!',
#  'show_number': '3216'}

# %%
import threading
def get_pred_ans(sample_questions, id, score, ans):
    for q in sample_questions:
        prediction = pipe.run(query = q['category'] +": "+ q['question'],params={"Retriever": {"top_k": 5}, "Reader": {"top_k": 1}})
        pred_ans = prediction['answers'][0]
        ans.append(pred_ans.to_dict()['answer'])
        score.append(pred_ans.to_dict()['score'])
threads = 4
jobs = []
for i in range(0, threads):
    score = list()
    ans = list()
    thread = threading.Thread(target=get_pred_ans(sample_questions, i, score, ans))
    jobs.append(thread)
for j in jobs:
    j.start()
for j in jobs:
    j.join()
print(len(score))
print(len(ans))
# Out:
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.82s/ Batches
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.16s/ Batches
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.72s/ Batches
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.77s/ Batches
# Inferencing Samples:   0%|        | 0/1 [00:01<?, ? Batches/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4114/588144160.py in <module>
#      11     score = list()
#      12     ans = list()
# ---> 13     thread = threading.Thread(target=get_pred_ans(sample_questions, i, score, ans))
#      14     jobs.append(thread)
#      15 for j in jobs:
#
# /tmp/ipykernel_4114/588144160.py in get_pred_ans(sample_questions, id, score, ans)
#       2 def get_pred_ans(sample_questions, id, score, ans):
#       3     for q in sample_questions:
# ----> 4         prediction = pipe.run(query = q['category'] +": "+ q['question'],params={"Retriever": {"top_k": 5}, "Reader": {"top_k": 1}})
#       5         pred_ans = prediction['answers'][0]
#       6         ans.append(pred_ans.to_dict()['answer'])
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/pipelines/standard_pipelines.py in run(self, query, params, debug)
#     336                       by this method under the key "_debug"
#     337         """
# --> 338         output = self.pipeline.run(query=query, params=params, debug=debug)
#     339         return output
#     340
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/pipelines/base.py in run(self, query, file_paths, labels, documents, meta, params, debug)
#     522                 try:
#     523                     logger.debug("Running node '%s` with input: %s", node_id, node_input)
# --> 524                     node_output, stream_id = self._run_node(node_id, node_input)
#     525                 except Exception as e:
#     526                     # The input might be a really large object with thousands of embeddings.
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/pipelines/base.py in _run_node(self, node_id, node_input)
#     449
#     450     def _run_node(self, node_id: str, node_input: Dict[str, Any]) -> Tuple[Dict, str]:
# --> 451         return self.graph.nodes[node_id]["component"]._dispatch_run(**node_input)
#     452
#     453     def run(  # type: ignore
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/nodes/base.py in _dispatch_run(self, **kwargs)
#     199         method with the correct run method.
#     200         """
# --> 201         return self._dispatch_run_general(self.run, **kwargs)
#     202
#     203     def _dispatch_run_batch(self, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/nodes/base.py in _dispatch_run_general(self, run_method, **kwargs)
#     243                 run_inputs[key] = value
#     244
# --> 245         output, stream = run_method(**run_inputs, **run_params)
#     246
#     247         # Collect debug information
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/nodes/reader/base.py in run(self, query, documents, top_k, labels, add_isolated_node_eval)
#      82         predict = self.timing(self.predict, "query_time")
#      83         if documents:
# ---> 84             results = predict(query=query, documents=documents, top_k=top_k)
#      85         else:
#      86             results = {"answers": []}
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/nodes/reader/base.py in wrapper(*args, **kwargs)
#     171                 self.__dict__[attr_name] = 0
#     172             tic = perf_counter()
# --> 173             ret = fn(*args, **kwargs)
#     174             toc = perf_counter()
#     175             self.__dict__[attr_name] += toc - tic
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/nodes/reader/farm.py in predict(self, query, documents, top_k)
#     892         # get answers from QA model
#     893         # TODO: Need fix in FARM's `to_dict` function of `QAInput` class
# --> 894         predictions = self.inferencer.inference_from_objects(
#     895             objects=inputs, return_json=False, multiprocessing_chunksize=1
#     896         )
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/modeling/infer.py in inference_from_objects(self, objects, return_json, multiprocessing_chunksize)
#     511         # then we can and should use inference from (input) objects!
#     512         # logger.warning("QAInferencer.inference_from_objects() will soon be deprecated. Use QAInferencer.inference_from_dicts() instead")
# --> 513         return self.inference_from_dicts(
#     514             dicts, return_json=return_json, multiprocessing_chunksize=multiprocessing_chunksize
#     515         )
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/modeling/infer.py in inference_from_dicts(self, dicts, return_json, multiprocessing_chunksize)
#     479                                     has been deprecated.
#     480         """
# --> 481         return Inferencer.inference_from_dicts(
#     482             self, dicts, return_json=return_json, multiprocessing_chunksize=multiprocessing_chunksize
#     483         )
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/modeling/infer.py in inference_from_dicts(self, dicts, return_json, multiprocessing_chunksize)
#     307             aggregate_preds = hasattr(self.model.prediction_heads[0], "aggregate_preds")
#     308
# --> 309         predictions: Any = self._inference_without_multiprocessing(dicts, return_json, aggregate_preds)
#     310         return predictions
#     311
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/modeling/infer.py in _inference_without_multiprocessing(self, dicts, return_json, aggregate_preds)
#     329         # TODO change format of formatted_preds in QA (list of dicts)
#     330         if aggregate_preds:
# --> 331             preds_all = self._get_predictions_and_aggregate(dataset, tensor_names, baskets)
#     332         else:
#     333             preds_all = self._get_predictions(dataset, tensor_names, baskets)
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/modeling/infer.py in _get_predictions_and_aggregate(self, dataset, tensor_names, baskets)
#     406                 # Aggregation works on preds, not logits. We want as much processing happening in one batch + on GPU
#     407                 # So we transform logits to preds here as well
# --> 408                 logits = self.model.forward(
#     409                     input_ids=batch["input_ids"],
#     410                     segment_ids=batch["segment_ids"],
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/modeling/model/adaptive_model.py in forward(self, input_ids, segment_ids, padding_mask, output_hidden_states, output_attentions)
#     494         """
#     495         # Run forward pass of language model
# --> 496         output_tuple = self.language_model.forward(
#     497             input_ids=input_ids,
#     498             segment_ids=segment_ids,
#
# ~/anaconda3/lib/python3.9/site-packages/haystack/modeling/model/language_model.py in forward(self, input_ids, attention_mask, segment_ids, output_hidden_states, output_attentions, return_dict)
#     342             params["output_attentions"] = output_attentions
#     343
# --> 344         return self.model(**params, return_dict=return_dict)
#     345
#     346
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     846             past_key_values_length=past_key_values_length,
#     847         )
# --> 848         encoder_outputs = self.encoder(
#     849             embedding_output,
#     850             attention_mask=extended_attention_mask,
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     522                 )
#     523             else:
# --> 524                 layer_outputs = layer_module(
#     525                     hidden_states,
#     526                     attention_mask,
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     407         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     408         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 409         self_attention_outputs = self.attention(
#     410             hidden_states,
#     411             attention_mask,
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     334         output_attentions: Optional[bool] = False,
#     335     ) -> Tuple[torch.Tensor]:
# --> 336         self_outputs = self.self(
#     337             hidden_states,
#     338             attention_mask,
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     220             value_layer = torch.cat([past_key_value[1], value_layer], dim=2)
#     221         else:
# --> 222             key_layer = self.transpose_for_scores(self.key(hidden_states))
#     223             value_layer = self.transpose_for_scores(self.value(hidden_states))
#     224
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
import json
with open('sample_questions_with_predicted.json','r') as file:
    sample_questions = json.load(file)

# %%
q = sample_questions[0]
print(q)
print(q['predicted_question'][0][0][10:])
# prediction = pipe.run(query = q['predicted_question'][0][0][10:],params={"Retriever": {"top_k": 5}, "Reader": {"top_k": 1}})
prediction['answers'][0]
# Out:
# {'category': 'COMMON BONDS', 'air_date': '1998-09-07', 'question': "'A game of footsie,<br />a bribe,<br />a drunk person'", 'value': '$500', 'answer': 'Things that are done under the table', 'round': 'Jeopardy!', 'show_number': '3216', 'predicted_question': [['question: What is the difference between a game of footsie,br />a bribe and a drunk person?']]}
# What is the difference between a game of footsie,br />a bribe and a drunk person?
# <Answer {'answer': 'Obi rejects', 'type': 'extractive', 'score': 0.07148900628089905, 'context': 'hips to students. A man offers a bribe on behalf of his sister, which Obi rejects. The girl herself visits Obi and tries to bribe him with sex for a s', 'offsets_in_document': [{'start': 1182, 'end': 1193}], 'offsets_in_context': [{'start': 70, 'end': 81}], 'document_id': 'a4614d69f5bebbed2c708de34bbc77df', 'meta': {'id': '775815', 'url': 'https://simple.wikipedia.org/wiki/No%20Longer%20at%20Ease', 'title': 'No Longer at Ease'}}>

# %%
import time
ans = []
score = []
timer = 0
for i in tqdm(range(len(sample_questions))):
    start = time.time()
    q = sample_questions[i]
    prediction = pipe.run(query = q['predicted_question'][0][0][10:],params={"Retriever": {"top_k": 5}, "Reader": {"top_k": 1}})
    pred_ans = prediction['answers'][0]
    timer += time.time()-start
    ans.append(pred_ans.to_dict()['answer'])
    score.append(pred_ans.to_dict()['score'])
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.03s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.39s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.18s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.66s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.52s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.40s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.31s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.52s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:17<00:00, 17.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:18<00:00, 18.33s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.34s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.45s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.34s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.83s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.80s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.81s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.81s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.25s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.78s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.53s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.83s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.90s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.03s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.93s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.28s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.53s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.89s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.21s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.30s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.54s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.64s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.04s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.82s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:28<00:00, 14.39s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.28s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.03s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.43s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.28s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.94s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.04s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.78s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.47s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.90s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.28s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.48s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.10s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.46s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.66s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.65s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.67s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.26s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.65s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.53s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.64s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.58s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.40s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.70s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.29s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.30s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.10s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.77s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.66s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.48s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.08s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.17s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:32<00:00, 16.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.06s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.39s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.27s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.69s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.39s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.89s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.25s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:20<00:00, 20.82s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.51s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:17<00:00, 17.03s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.54s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.77s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.67s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.72s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:22<00:22, 22.93s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:32<00:00, 16.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.88s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.77s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.55s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.10s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.19s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.46s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.10s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.05s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.21s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:27<00:00, 13.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.07s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:18<00:00, 18.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.31s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:24<00:00, 12.03s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.08s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.19s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.21s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.19s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.48s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.67s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.45s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.25s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.28s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:24<00:00, 12.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.48s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.39s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.45s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:17<00:00, 17.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.48s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:18<00:00, 18.30s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.33s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.40s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.52s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.46s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.88s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.94s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.57s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:20<00:00, 20.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.21s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.55s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.53s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.58s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.80s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.21s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.55s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.88s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.53s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.06s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.10s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/3 [00:00<?, ? Batches/s]
# Inferencing Samples:  33%|▎| 1/3 [00:22<00:45, 22.81s/ Batches
# Inferencing Samples:  67%|▋| 2/3 [00:45<00:22, 22.83s/ Batches
# Inferencing Samples: 100%|█| 3/3 [00:47<00:00, 15.96s/ Batches
# ERROR:haystack.modeling.model.predictions:Invalid end offset:
# (-31519, -30846) with a span answer.
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.91s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.54s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:23<00:00, 23.55s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.03s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.47s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:22<00:00, 23.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# ...
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.91s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.18s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.45s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:25<00:00, 12.65s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.18s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.91s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:21<00:00, 21.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.89s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.21s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.46s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.90s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.40s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.43s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.42s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:32<00:00, 16.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.51s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.43s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:30<00:00, 15.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.58s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.55s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.57s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.06s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.34s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.03s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.43s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.09s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  6.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.51s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.66s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.06s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:40<00:00, 20.43s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.25s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.19s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.31s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.62s/ Batches

# %%
timer/len(sample_questions)
# Out:
# 7.134882670879364

# %%
with open('haystack_ans.txt','r') as file:
    og_ans = json.load(file)
with open('haystack_score.txt','r') as file:
    og_score = json.load(file)

# %%
ans[0]
# Out:
# 'Obi rejects'

# %%
def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def compute_exact_match(prediction, truth):
    return int(normalize_text(prediction) == normalize_text(truth))

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()
    
    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)
    
    common_tokens = set(pred_tokens) & set(truth_tokens)
    
    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0
    
    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)
    
    return 2 * (prec * rec) / (prec + rec)
#https://qa.fastforwardlabs.com/no%20answer/null%20threshold/bert/distilbert/exact%20match/f1/robust%20predictions/2020/06/09/Evaluating_BERT_on_SQuAD.html#F1

# %%
f1s = 0
ems = 0
for idx, q in enumerate(sample_questions):
    f1 = compute_f1(ans[idx], q['answer'])
    em = compute_exact_match(ans[idx], q['answer'])
    f1s += f1
    ems += em
print(f1s/len(ans))
print(ems/len(ans))
# Out:
# 0.051408561441512575
# 0.034

# %%
f1s = 0
ems = 0
for idx, q in enumerate(sample_questions[:len(ans)]):
    f1 = compute_f1(ans[idx], q['answer']) / score[idx]
    em = compute_exact_match(ans[idx], q['answer']) / score[idx]
    f1s += f1
    ems += em
print(f1s/len(ans))
print(ems/len(ans))
# Out:
# 0.4840575724220811
# 0.24649207638425363

# %%
with open('haystack_score_reform_q.txt','w') as file:
    json.dump(score, file)

# %%
with open('haystack_ans_reform_q.txt','w') as file:
    json.dump(ans, file)

# %%
import time
rest_ans = []
rest_score = []
timer = 0
for i in tqdm(range(719,len(sample_questions))):
    start = time.time()
    q = sample_questions[i]
    prediction = pipe.run(query = q['category'] +": "+ q['question'],params={"Retriever": {"top_k": 5}, "Reader": {"top_k": 1}})
    pred_ans = prediction['answers'][0]
    timer += time.time()-start
    rest_ans.append(pred_ans.to_dict()['answer'])
    rest_score.append(pred_ans.to_dict()['score'])
# Out:
#   0%|          | 0/281 [00:00<?, ?it/s]
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.13s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.31s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.30s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.32s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.58s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.45s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.42s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:31<00:00, 15.70s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.18s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:22<00:00, 22.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.68s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.29s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.04s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.43s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.64s/ Batches
#
# Inferencing Samples:   0%|        | 0/3 [00:00<?, ? Batches/s]
# Inferencing Samples:  33%|▎| 1/3 [00:23<00:46, 23.41s/ Batches
# Inferencing Samples:  67%|▋| 2/3 [00:46<00:23, 23.41s/ Batches
# Inferencing Samples: 100%|█| 3/3 [00:48<00:00, 16.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:24<00:24, 24.80s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:27<00:00, 13.52s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.18s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.72s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:19<00:00, 19.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:18<00:00, 18.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.07s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.10s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.94s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.57s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.58s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.83s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.28s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.90s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.89s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.49s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.77s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.93s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.29s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.33s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.51s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.09s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.19s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.77s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.64s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.88s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.55s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.37s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:46<00:00, 23.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.48s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.72s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:22<00:00, 22.96s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:15<00:00, 15.02s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.57s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.27s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.41s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:29<00:00, 14.52s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.57s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.27s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.72s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.35s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.36s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.05s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.57s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.14s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.50s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.99s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.19s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.40s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:31<00:00, 15.72s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.89s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:11<00:00, 11.12s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.86s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.88s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.63s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  8.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.46s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  6.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.54s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:18<00:00, 18.72s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.06s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  6.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.98s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.45s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.11s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.30s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:21<00:00, 21.16s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.75s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.43s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.85s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:13<00:00, 13.30s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.76s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.40s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.41s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.48s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.97s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.42s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.38s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.04s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.44s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:18<00:00, 18.66s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.65s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.23s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:12<00:00, 12.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.69s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  7.15s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.62s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:24<00:24, 24.71s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:25<00:00, 12.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.60s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.24s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:09<00:00,  9.80s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.52s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.61s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.20s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.84s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:08<00:00,  8.01s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:10<00:00, 10.67s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/2 [00:00<?, ? Batches/s]
# Inferencing Samples:  50%|▌| 1/2 [00:23<00:23, 23.44s/ Batches
# Inferencing Samples: 100%|█| 2/2 [00:24<00:00, 12.10s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:20<00:00, 20.54s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.59s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.73s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.64s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:16<00:00, 16.92s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.21s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.58s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:07<00:00,  8.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.95s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:06<00:00,  6.17s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/3 [00:00<?, ? Batches/s]
# Inferencing Samples:  33%|▎| 1/3 [00:23<00:46, 23.42s/ Batches
# Inferencing Samples:  67%|▋| 2/3 [00:46<00:23, 23.42s/ Batches
# Inferencing Samples: 100%|█| 3/3 [00:50<00:00, 16.99s/ Batches
# ERROR:haystack.modeling.model.predictions:Invalid end offset:
# (-29301, -29291) with a span answer.
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:01<00:00,  1.87s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.00s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:02<00:00,  2.22s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.74s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:03<00:00,  3.37s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:05<00:00,  5.56s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:04<00:00,  4.66s/ Batches
#
# Inferencing Samples:   0%|        | 0/1 [00:00<?, ? Batches/s]
# Inferencing Samples: 100%|█| 1/1 [00:14<00:00, 14.63s/ Batches

# %%
og_full_ans = np.append(og_ans, rest_ans)

# %%
og_full_score = np.append(og_score,rest_score)

# %%
f1s = 0
ems = 0
for idx, q in enumerate(sample_questions):
    f1 = compute_f1(og_full_ans[idx], q['answer'])
    em = compute_exact_match(og_full_ans[idx], q['answer'])
    f1s += f1
    ems += em
print(f1s/len(ans))
print(ems/len(ans))
# Out:
# 0.045350003582828806
# 0.03

# %%
f1s = 0
ems = 0
for idx, q in enumerate(sample_questions):
    f1 = compute_f1(og_full_ans[idx], q['answer']) / og_full_score[idx]
    em = compute_exact_match(og_full_ans[idx], q['answer']) / og_full_score[idx]
    f1s += f1
    ems += em
print(f1s/len(ans))
print(ems/len(ans))
# Out:
# 0.7675834374679207
# 0.534341242236703

# %%
with open('sample_questions_with_predicted_and_context.json','r') as file:
    sq = json.load(file)

# %%
sq[0]
# Out:
# {'category': 'COMMON BONDS',
#  'air_date': '1998-09-07',
#  'question': "'A game of footsie,<br />a bribe,<br />a drunk person'",
#  'value': '$500',
#  'answer': 'Things that are done under the table',
#  'round': 'Jeopardy!',
#  'show_number': '3216',
#  'predicted_question': [['question: What is the difference between a game of footsie,br />a bribe and a drunk person?']],
#  'text': ['Uses of bond, bonds, bonded, and bonding:\n\nFinancial bonds \n Bond (finance), in finance, a debt security, issued by Issuer\n Government bond, a bond issued by a national government\n Bond market, a financial market for bonds\n Investment bond, a life assurance based single premium investment\n A surety bond is a three party contract, where the surety promises to pay the obligee for non-performance or dishonesty by the principal.  Workers in many jobs must be bonded.   \n A performance bond is a surety bond for completion of work under a contract\n A bail bond is a surety bond for return of a person to a court\n Tenancy bond (or damage deposit), a deposit taken by a landlord in relation to rental of a property\n Catastrophe bond (or cat bond), a form of reinsurance\n Bonded labor (or debt bondage) is a system of servitude where someone must work to pay off a debt\n\nPhysical sciences \n Bond number, in fluid mechanics, a dimensionless number expressing the ratio of gravitational forces to surface tension forces\n Chemical bond, the physical phenomenon of chemical substances being held together by attraction of atoms\n Covalent bond, a chemical bond between two non-metals\n Ionic bond, bonding of a non-metal and a metal\n Metallic bond, bonding between atoms and metals\n Bond albedo is a measure of electromagnetic radiation of an astronomical body\n A
#   '\n\nA\n Adobe\n Acrobat\n Algorithm\n AMD\n Android\n API\n Apple\n Application\n Analog\n Alpha\n\nB\n\n Boot\n binary\n BIOS\n bitcoin\n byte\n bot\n Botnet\n Browser\n\nC \n C programming language\n Cable\n Cache memory\n Captcha\n Connection\n Control\n Cookie\n C++\n Computer\n\nD\n data\n database\n datalake\n Debian\n decompress\n desktop\n dialer\n digital\n document\n disk operating system (redirect (or disambig) from DOS)\n download\n\nE\n ENIAC Electronic Numerical Integrator and Calculator\n electricity\n email\n email attachment\n Encarta encyclopedia\n Epiphany web browser\n End User License Agreement (redirect from EULA)\n Explorer\n ext2 filesystem type\n ext3 filesystem type\n\nF\n File allocation table (disambiguation from FAT or fat)\n FAT16 filesystem\n FAT32 filesystem\n file\n file types by ending\n filesharing\n filesystem\n firewall\n folder\n footnotes\n format\n FreeBSDK\n freeware\n FTP\n Facebook\n function\n font\n\nG\n gigabyte (redir from gb)\n Gimp\n Gmail\n Gnome\n Google\n GNU\n GnuPG\n GPU\n Google Nest\n\nH\n hacker\n hard disk (redirects from hard drive, hard disk drive, hard disk)\n hardware\n Hash_function\n HDMI\n home page\n HTML\n HTTP\n HTTP_Cookie\n\nI\n Intel\n Icons\n Input device\n Internet\n Integrated circuit-IC\n\nJ\n\n MarA jio\n Joo\n Jio\n\n Java\n JavaScript\n J#\n\nK\n KDE*\n kernel\n keyboard\n key\n keyword\n\nL\n laptop\n licensing examples for computer software\n link\n Linux\n Lavasoft\n Live CD\n LibreOffice\n\nM\n Macintosh\n Mac OS\n Mac OS X\n Malware\nMainframe Computer \n Mandrake Linux\n Martus\n md5\n media\n megabyte (redir or disamb from mb)\n Microsoft\n modify\n monitor\n Motherboard\n mouse\n Mozilla web browser\n Mozilla Firefox web browser\n Modem\n mp4\n mpeg-4\n\nN \n\n NTFS filesystem type\n Netscape\n Netscape Navigator web browser\n network\n NNTP\n non-commercial\n notebook computer\n notepad\n Nvidia\n\nO\n ogg file format for multimedia\n OpenOffice.org\n Open Site\n open source\n Opera web browser\n operating system\n operating systems, a list\n\nP\n page\n Perl\n personal computer (PC)\n Petabyte\n pdf or more likely PDF\n peer to peer, P2P\n PGP\n PHP\n proprietary\n piracy\n pirate\n plug-in\n Python\n popup\n printer\n privacy\n program\n program release\n Python\n PRINT\n\nQ\n QNX\n QuickBasic\n QuickTime.\n QWERTY\n\nR\n Random_access_memory(redirect from RAM)\n ReactOS\n Read-only_memory(Redirect from ROM)\n RedHat\n Reiser FS filesystem type\n root\n RSA\n Recycle Bin\n Reboot\n RISC reduced instruction set computer\n\nS\n scan\n search engine\n security\n server\n shared source\n shareware\n software\n spam\n spamming\n Spreadsheet\n spyware\n super computer\n super user\n surfing the internet\n Suse\n SDK\n SSD\n system\n synergy (synergistic)\n\nT\n training for computers\n Trojan horse\n Terabyte (TB)\n Tablet\n\nU\n Ubuntu\n undo\n UNIX\n update\n upload\n user\n USB\n\nV\n version\n virtual community\n Visual Studio\n Visual Basic\n virus\n Vulnerability32]✓\n VPN\n\nW\n Windows\n Wine (software)\nWi-Fi\n\nX\n Xine\n XML\n x86, x32(processor)\n x86-64, x64(processor architecture)\n\nY\n Yahoo!\n Yotabyte\n\nZ\n Z (file format)\nZoom in - Zoom out\nZIP\nZettabyte(ZB)\n\nOther websites \n A Gnu Dictionary of Computing - downloadable\n\nComputing\nComputer-related lists\nComputers']}

# %%
from transformers import pipeline
question_answerer = pipeline("question-answering", model='distilbert-base-cased-distilled-squad')

context = r"""
Extractive Question Answering is the task of extracting an answer from a text given a question. An example     of a
question answering dataset is the SQuAD dataset, which is entirely based on that task. If you would like to fine-tune
a model on a SQuAD task, you may leverage the examples/pytorch/question-answering/run_squad.py script.
"""

result = question_answerer(question="What is a good example of a question answering dataset?",     context=context)
print(
f"Answer: '{result['answer']}', score: {round(result['score'], 4)}, start: {result['start']}, end: {result['end']}")
# Out:
# Downloading config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/249M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/426k [00:00<?, ?B/s]
# Answer: 'SQuAD dataset', score: 0.5152, start: 151, end: 164

# %%
timer = 0
f1s = 0
ems = 0
f1s_s = 0
ems_s = 0
for i in tqdm(range(10)):
    q = sq[i]
    start = time.time()
    best_score = -1
    for j in range(5):
        context = q['text'][j]
        res = question_answerer(question=q['predicted_question'][0][0][10:],context=context)
        if res['score'] > best_score:
            best_score = res['score']
            best_ans = res['answer']
    timer += time.time()-start
    f1 = compute_f1(best_ans, q['answer'])
    em = compute_exact_match(best_ans, q['answer'])
    f1s += f1
    ems += em
    f1s_s += f1/best_score
    ems_s += em/best_score
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
f1s/511
# Out:
# 0.035756220296337723

# %%
ems/511
# Out:
# 0.019569471624266144

# %%
timer/511
# Out:
# 17.305903616716716

# %%
f1s_s/511
# Out:
# 0.11340922481709052

# %%
ems_s/511
# Out:
# 0.04139581521826604

# %%
print(f1s/10)
print(ems/10)
# Out:
# 0.019999999999999997
# 0.0

# %%
print(timer/10)
# Out:
# 3.2207370519638063

# %%
sq[14]['text'][2]
# Out:
# '\n\n8001–8100 \n\n|-bgcolor=#d6d6d6\n| 8001 Ramsden ||  ||  || October 4, 1986 || Kleť || A. Mrkos || THM || align=right | 13 km || \n|-id=002 bgcolor=#fefefe\n| 8002 Tonyevans ||  ||  || December 4, 1986 || Kleť || A. Mrkos || NYS || align=right | 2.7 km || \n|-id=003 bgcolor=#fefefe\n| 8003 Kelvin || 1987 RJ ||  || September 1, 1987 || La Silla || E. W. Elst || — || align=right | 4.9 km || \n|-id=004 bgcolor=#d6d6d6\n| 8004 || 1987 RX || — || September 12, 1987 || La Silla || H. Debehogne || — || align=right | 8.6 km || \n|-id=005 bgcolor=#E9E9E9\n| 8005 Albinadubois || 1988 MJ ||  || June 16, 1988 || Palomar || E. F. Helin || — || align=right | 6.5 km || \n|-id=006 bgcolor=#E9E9E9\n| 8006 Tacchini || 1988 QU ||  || August 22, 1988 || Bologna || San Vittore Obs. || — || align=right | 6.5 km || \n|-id=007 bgcolor=#E9E9E9\n| 8007 ||  || — || September 8, 1988 || La Silla || H. Debehogne || MIS || align=right | 9.0 km || \n|-id=008 bgcolor=#E9E9E9\n| 8008 ||  || — || October 10, 1988 || Gekko || Y. Oshima || AST || align=right | 13 km || \n|-id=009 bgcolor=#E9E9E9\n| 8009 Béguin ||  ||  || January 25, 1989 || Caussols || C. Pollas || PAL || align=right | 5.9 km || \n|-id=010 bgcolor=#d6d6d6\n| 